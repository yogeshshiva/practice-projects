# %% [markdown]
# # Basic Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Project Description

# %% [markdown]
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.

# %% [markdown]
# # Dataset Link :-

# %% [markdown]
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/Automobile_insurance_fraud.csv

# %% [markdown]
# # Import The Dataset And Create the DataFrame

# %%
df = pd.read_csv(r'E:\Flip Robo\dataset\Automobile_insurance_fraud.csv')
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %% [markdown]
# # Basic Data Exploration

# %% [markdown]
# In this operation, we will perform below operation to check the dataset.

# %% [markdown]
# 1) Head, tail, sample of the dataset.
# 2) Shape of the dataset.
# 3) Information of the dataset.
# 4) Summary of the dataset.

# %% [markdown]
# # Head, Tail, Sample of the dataset

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %% [markdown]
# The head attribute give us top 5 row's which are present in this dataset

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %% [markdown]
# The tail attribute give us last 5 row's which are present in this dataset.

# %%
df.sample(5)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 369                 309   47         369048       05-06-2011           IL
# 735                 293   45         235097       28-04-1992           IL
# 284                 189   36         967756       28-04-2007           OH
# 981                  50   44         525862       18-10-2000           OH
# 410                 283   43         631565       14-07-1997           IN
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 369   500/1000                500                1527.95               0
# 735    100/300               1000                1119.23               0
# 284    250/500               2000                1388.58               0
# 981    250/500               2000                1188.51               0
# 410    100/300               2000                1161.91               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %% [markdown]
# The Sample attribute tell us random data which are present in this dataset.

# %% [markdown]
# # Shape of the dataset

# %%
df.shape
# Out:
# (1000, 40)

# %%
print("Number of Rows :",df.shape[0])
print("Number of Columns :",df.shape[1])
# Out:
# Number of Rows : 1000
# Number of Columns : 40

# %% [markdown]
# The Shape attribute give us total no of rows and total no of colume which are present in this dataset.

# %% [markdown]
# # Information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# The info attribute give us brief about the dataset which include indexing type, column type, null values, and memory usage.

# %% [markdown]
# # Summary of the dataset

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %% [markdown]
# The describe attribute give us whole stastical information which are present in this dataset.

# %% [markdown]
# # Handling missing values

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# here, we can see _c39 column have no data present it means whole value are null value so we will drop this column

# %%
df.drop('_c39',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %% [markdown]
# Now, we can see no null values are present in this dataset.

# %% [markdown]
# Now we will see this null value by visualization.

# %%
sns.heatmap(df.isnull(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# here, we can clearly visualize no null values are present in this dataset.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univerate Analysis

# %% [markdown]
# When we are doing any analysis with single column that is called Univerate Analysis

# %%
sns.countplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# here, we can see maximum Insurance Claim is not Fraud and little bit Insurance Claim is Fraud.

# %% [markdown]
# And we can also see this data is Imbalance data we can solve this by later part.

# %%
plt.figure(figsize=(18,8))
sns.countplot(df['auto_year'])
# Out:
# <AxesSubplot:xlabel='auto_year', ylabel='count'>

# %% [markdown]
# Here, we can see maximum vehicle manufactured in year 1995, 1999, 2005, 2011 etc..

# %%
plt.figure(figsize=(35,17))
sns.countplot(df['auto_model'])
# Out:
# <AxesSubplot:xlabel='auto_model', ylabel='count'>

# %% [markdown]
# here, we can see maximum model RAM, Wrangler are used

# %%
plt.figure(figsize=(16,7))
sns.countplot(df['auto_make'])
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='count'>

# %% [markdown]
# Here, we can see maximum vehicle make in Saab, Dodge, Suburu etc..

# %%
sns.distplot(df['vehicle_claim'])
# Out:
# <AxesSubplot:xlabel='vehicle_claim', ylabel='Density'>

# %% [markdown]
# here, we can see maximum vehicle Claim lies between 30000 to 58000

# %%
sns.distplot(df['property_claim'])
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='Density'>

# %% [markdown]
# Here, we can see Maximum Property Claim lies between 5000 to 9000

# %%
sns.distplot(df['injury_claim'])
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='Density'>

# %% [markdown]
# here, we can see maximum physical injury claim lies between 5000 to 8000

# %%
sns.distplot(df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Density'>

# %% [markdown]
# here, we can see total claim amount lies between 40000 to 80000

# %%
df['police_report_available'].replace('?','NO',inplace=True)

# %%
sns.countplot(df['police_report_available'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='count'>

# %% [markdown]
# here, we can see maximum people doesn't report to police while damage their vehicle

# %%
sns.countplot(df['witnesses'])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='count'>

# %% [markdown]
# here, we can see all people have witness

# %%
sns.distplot(df['policy_annual_premium'])
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='Density'>

# %% [markdown]
# here, we can see the policy annual premium lies between 1000 to 1500

# %%
sns.countplot(df['policy_deductable'])
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='count'>

# %% [markdown]
# here, we can see the amount of money that a customer is responsible for paying toward an insured loss is mostly pay 1000

# %%
sns.countplot(df['policy_state'])
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %% [markdown]
# here, we can see maximum policy state is OH.

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# here, we can see maximum age lies between 30 to 48

# %% [markdown]
# # Convert Columns from string to Numerical values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
# Encoding Categorical Columns using OrdinalEncoder
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1, 1))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   float64
#  4   policy_state                 1000 non-null   float64
#  5   policy_csl                   1000 non-null   float64
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   float64
#  11  insured_education_level      1000 non-null   float64
#  12  insured_occupation           1000 non-null   float64
# ...

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_bind_date                       0.055055  0.056538       0.045713
# policy_state                          -0.000328 -0.014533       0.072815
# policy_csl                            -0.026819 -0.015185       0.038917
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# insured_sex                            0.060925  0.073337       0.004564
# insured_education_level               -0.000833  0.000969      -0.037264
# ...

# %%
plt.figure(figsize=(50,24))
sns.heatmap(df.corr(),annot=True,cmap='Blues_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Handling Imbalance Dataset

# %% [markdown]
# To solve Imbalance dataset using SMOTE (Synthetic Minority Oversampling Technique)

# %%
from imblearn.over_sampling import SMOTE

# %%
X = df.drop('fraud_reported',axis=1)
y = df['fraud_reported']

# %%
X_res, y_res = SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# 1.0    753
# 0.0    753
# Name: fraud_reported, dtype: int64

# %% [markdown]
# Now, we can see our data is balanced

# %% [markdown]
# # Splitting the dataset into the training set and test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res,y_res, test_size=0.2, random_state=2)

# %%
X_train.shape, X_test.shape
# Out:
# ((1204, 38), (302, 38))

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()

# %%
X_train_res = st.fit_transform(X_train)
X_test_res = st.fit_transform(X_test)

# %% [markdown]
# # Applying PCA

# %% [markdown]
# Principle Component Analysis (PCA)

# %% [markdown]
# To reduce the dimensionality of large dataset by transforming a large set of variables into a smaller one.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=0.90)

# %%
X_train_res = pca.fit_transform(X_train_res)
X_test_res = pca.transform(X_test_res)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.10953107, 0.05334228, 0.04651689, 0.03755353, 0.03615484,
#        0.03408845, 0.03361645, 0.03228335, 0.03197441, 0.03053247,
#        0.0300232 , 0.02934757, 0.02841404, 0.02797502, 0.02716874,
#        0.02667479, 0.02626923, 0.02562553, 0.02477758, 0.02455884,
#        0.0241683 , 0.02384028, 0.02314093, 0.02233852, 0.02148735,
#        0.0209886 , 0.0200498 , 0.01927993, 0.01902025])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9107422351365975

# %% [markdown]
# Pca contains 39 variables into my dataset and output is 29 components.

# %% [markdown]
# So, we can say that 29 components retaining 91% of information of our target dataset

# %% [markdown]
# # Model Training

# %% [markdown]
# When we are analysis my dataset then i was find in my dataset Classification problem is going on

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()

# %%
log.fit(X_train_res,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test_res)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.6920529801324503

# %% [markdown]
# here, we can see LogisticRegression is 69% accurate in this dataset.

# %% [markdown]
# now we will check precision score, recall score and f1 score

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
print("Precision Score is :",precision_score(y_test,y_pred1))
print("Recall Score is :",recall_score(y_test,y_pred1))
print("F1 Score is :",f1_score(y_test,y_pred1))
# Out:
# Precision Score is : 0.6729559748427673
# Recall Score is : 0.722972972972973
# F1 Score is : 0.6970684039087949

# %% [markdown]
# # SVC

# %% [markdown]
# Support vector classifier (svc)

# %%
from sklearn import svm

# %%
svm = svm.SVC()

# %%
svm.fit(X_train_res,y_train)
# Out:
# SVC()

# %%
y_pred2 = svm.predict(X_test_res)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8377483443708609

# %% [markdown]
# here, we can see SVC is 83% accurate in this dataset.

# %% [markdown]
# Now we will check precision score recall score f1 score

# %%
print("Precision Score is :",precision_score(y_test,y_pred2))
print("Recall Score is :",recall_score(y_test,y_pred2))
print("F1 Score is :",f1_score(y_test,y_pred2))
# Out:
# Precision Score is : 0.7894736842105263
# Recall Score is : 0.9121621621621622
# F1 Score is : 0.8463949843260189

# %% [markdown]
# # KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train_res,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred3 = knn.predict(X_test_res)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.6456953642384106

# %% [markdown]
# here, we can see KNeighbors Classifier is 64% accurate in this dataset.

# %% [markdown]
# now we will check precision score recall score and f1 score

# %%
print("Precision Score is :",precision_score(y_test,y_pred3))
print("Recall Score is :",recall_score(y_test,y_pred3))
print("F1 Score is :",f1_score(y_test,y_pred3))
# Out:
# Precision Score is : 0.5810276679841897
# Recall Score is : 0.9932432432432432
# F1 Score is : 0.7331670822942643

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train_res,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4 = dt.predict(X_test_res)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.7384105960264901

# %% [markdown]
# here, we can see decision tree is 73% accurate in this dataset

# %% [markdown]
# Now we will check precision score recall score and f1 score

# %%
print("Precision Score is :",precision_score(y_test,y_pred4))
print("Recall Score is :",recall_score(y_test,y_pred4))
print("F1 Score is :",f1_score(y_test,y_pred4))
# Out:
# Precision Score is : 0.7346938775510204
# Recall Score is : 0.7297297297297297
# F1 Score is : 0.7322033898305085

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train_res,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred5 = rf.predict(X_test_res)

# %%
accuracy_score(y_test,y_pred5)
# Out:
# 0.8576158940397351

# %% [markdown]
# here, we can see RandomForest is 85% accurate in this dataset

# %% [markdown]
# Now we will check precision score recall score and f1 score

# %%
print("Precision Score is :",precision_score(y_test,y_pred5))
print("Recall Score is :",recall_score(y_test,y_pred5))
print("F1 Score is :",f1_score(y_test,y_pred5))
# Out:
# Precision Score is : 0.8523489932885906
# Recall Score is : 0.8581081081081081
# F1 Score is : 0.8552188552188552

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(X_train_res,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred6 = gbc.predict(X_test_res)

# %%
accuracy_score(y_test,y_pred6)
# Out:
# 0.8079470198675497

# %% [markdown]
# here, we can see Gradient Boosting is 80% accurate in this dataset

# %% [markdown]
# we will check precision score recall score and f1 score

# %%
print("Precision Score is :",precision_score(y_test,y_pred6))
print("Recall Score is :",recall_score(y_test,y_pred6))
print("F1 Score is :",f1_score(y_test,y_pred6))
# Out:
# Precision Score is : 0.7710843373493976
# Recall Score is : 0.8648648648648649
# F1 Score is : 0.8152866242038217

# %% [markdown]
# So let's visualize the result to find our best model

# %%
final_data = pd.DataFrame({'Models':['LR','SVC','KNN','DT','RF','GBC'],
                          'ACC':[accuracy_score(y_test,y_pred1)*100,
                                accuracy_score(y_test,y_pred2)*100,
                                accuracy_score(y_test,y_pred3)*100,
                                accuracy_score(y_test,y_pred4)*100,
                                accuracy_score(y_test,y_pred5)*100,
                                accuracy_score(y_test,y_pred6)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  69.205298
# 1    SVC  83.774834
# 2    KNN  64.569536
# 3     DT  73.841060
# 4     RF  85.761589
# 5    GBC  80.794702

# %%
sns.barplot(final_data['Models'],final_data['ACC'])
# Out:
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %% [markdown]
# here, we can clearly visualize Rf is best perform in this dataset so we can use Rf from prediction

# %% [markdown]
# # Save the Model

# %%
X = df.drop('fraud_reported',axis=1)
y = df['fraud_reported']

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res, y_res = SMOTE().fit_resample(X,y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()

# %%
X = st.fit_transform(X_res)

# %%
X = pca.fit_transform(X)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf,'Insurance Claim')
# Out:
# ['Insurance Claim']

# %%
model = joblib.load('Insurance Claim')

# %% [markdown]
# So now let's perform prediction using this save model

# %% [markdown]
# # Prediction on New Data

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')>

# %%
new_data = pd.DataFrame({'months_as_customer':333, 'age':25, 'policy_number':837382, 'policy_bind_date':434.0,
       'policy_state':0, 'policy_csl':1.2, 'policy_deductable':1010,
       'policy_annual_premium':1444.55, 'umbrella_limit':9484844, 'insured_zip':8484848, 'insured_sex':44,
       'insured_education_level':643, 'insured_occupation':764, 'insured_hobbies':66,
       'insured_relationship':8484, 'capital-gains':8484, 'capital-loss':888,
       'incident_date':777, 'incident_type':3838, 'collision_type':7773, 'incident_severity':6363,
       'authorities_contacted':747, 'incident_state':8484, 'incident_city':888,
       'incident_location':3838, 'incident_hour_of_the_day':333,
       'number_of_vehicles_involved':3333, 'property_damage':22, 'bodily_injuries':939,
       'witnesses':2, 'police_report_available':1, 'total_claim_amount':74847,
       'injury_claim':7575, 'property_claim':555, 'vehicle_claim':55454, 'auto_make':12.3,
       'auto_model':3.4, 'auto_year':2004},index=[0])

# %%
new_data
# Out:
#    months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                 333   25         837382             434.0             0
#
#    policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0         1.2               1010                1444.55         9484844
#
#    insured_zip  ...  bodily_injuries  witnesses  police_report_available  \
# 0      8484848  ...              939          2                        1
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               74847          7575             555          55454       12.3
#
#    auto_model  auto_year
# 0         3.4       2004
#
# [1 rows x 38 columns]

# %%
test = pca.transform(st.transform(new_data))

# %%
result = model.predict(test)

# %%
if result[0] == 1:
    print("Insurance claim is Fraud")
else:
    print("Insurance claim is not Fraud")
# Out:
# Insurance claim is not Fraud
